# %%
import pandas as pd

# %%
sample = pd.read_csv(r"C:\Users\AEPAC\Desktop\Sample.csv")

# %%
sample.head()
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
sample.columns
# Out:
# Index(['Order Date', 'Customer Name', 'Segment', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Profit'],
#       dtype='object')

# %%
pd.pivot_table?

# %%
pd.pivot_table(data = sample, index = ["State"])
# Out:
#                        Postal Code      Profit  Quantity        Sales
# State
# Alabama               35994.573770   94.865989  4.196721   319.846557
# Arizona               85277.348214  -15.303235  3.848214   157.508933
# Arkansas              72321.816667   66.811452  4.000000   194.635500
# California            92145.246877   38.171608  3.831584   228.729451
# Colorado              80295.758242  -35.867351  3.807692   176.418231
# Connecticut            6475.670732   42.823071  3.426829   163.223866
# Delaware              19755.250000  103.930988  3.822917   285.948635
# District of Columbia  20016.000000  105.958930  4.000000   286.502000
# Florida               33003.198433   -8.875461  3.600522   233.612815
# Georgia               30899.347826   88.315453  3.831522   266.825217
# Idaho                 83462.333333   39.367767  3.047619   208.689810
# Illinois              60719.048780  -25.625787  3.750000   162.939230
# ...

# %%
pd.pivot_table(sample, index = ["Segment","State"]).head()
# Out:
#                       Postal Code     Profit  Quantity       Sales
# Segment  State
# Consumer Alabama     36211.920000  68.443756  4.080000  301.501600
#          Arizona     85284.045455 -12.936843  3.909091  149.312927
#          Arkansas    72331.000000  85.211678  4.000000  237.892162
#          California  92135.416985  36.616450  3.894084  219.118397
#          Colorado    80288.431579 -16.995265  4.021053  166.257811

# %%
pd.pivot_table(sample, index = ["Segment","State"], values = ["Sales","Profit"])
# Out:
#                                Profit        Sales
# Segment     State
# Consumer    Alabama         68.443756   301.501600
#             Arizona        -12.936843   149.312927
#             Arkansas        85.211678   237.892162
#             California      36.616450   219.118397
#             Colorado       -16.995265   166.257811
# ...                               ...          ...
# Home Office Virginia        39.169116   165.591333
#             Washington      42.894352   250.476400
#             West Virginia   87.625067   178.826667
#             Wisconsin       54.632961   195.950714
#             Wyoming        100.196000  1603.136000
#
# [140 rows x 2 columns]

# %%
import numpy as np
pd.pivot_table(sample, index = ["Segment","State"], values = ["Sales","Profit"],
              aggfunc=np.sum)
# Out:
#                                Profit       Sales
# Segment     State
# Consumer    Alabama         1711.0939    7537.540
#             Arizona        -1423.0527   16424.422
#             Arkansas        3152.8321    8802.010
#             California     38374.0392  229636.080
#             Colorado       -1614.5502   15794.492
# ...                               ...         ...
# Home Office Virginia        1762.6102    7451.610
#             Washington      4289.4352   25047.640
#             West Virginia    262.8752     536.480
#             Wisconsin       1529.7229    5486.620
#             Wyoming          100.1960    1603.136
#
# [140 rows x 2 columns]

# %%
pd.pivot_table(sample, index = ["Segment","State"], values = ["Sales","Profit"],
              aggfunc=[np.sum, len])
# Out:
#                                   sum                 len
#                                Profit       Sales  Profit   Sales
# Segment     State
# Consumer    Alabama         1711.0939    7537.540    25.0    25.0
#             Arizona        -1423.0527   16424.422   110.0   110.0
#             Arkansas        3152.8321    8802.010    37.0    37.0
#             California     38374.0392  229636.080  1048.0  1048.0
#             Colorado       -1614.5502   15794.492    95.0    95.0
# ...                               ...         ...     ...     ...
# Home Office Virginia        1762.6102    7451.610    45.0    45.0
#             Washington      4289.4352   25047.640   100.0   100.0
#             West Virginia    262.8752     536.480     3.0     3.0
#             Wisconsin       1529.7229    5486.620    28.0    28.0
#             Wyoming          100.1960    1603.136     1.0     1.0
#
# [140 rows x 4 columns]

# %%
pd.pivot_table(sample, index = ["Category"],values = ["Sales"], columns = ["Segment"],
              aggfunc=np.sum)
# Out:
#                       Sales
# Segment            Consumer    Corporate  Home Office
# Category
# Furniture        391049.312  229019.7858  121930.6975
# Office Supplies  363952.136  230676.4620  124418.4340
# Technology       406399.897  246450.1190  183304.0170

# %%
pd.pivot_table(sample, index = ["Category"],values = ["Sales"], columns = ["Segment"],
              aggfunc=np.sum, fill_value=0)
# Out:
#                       Sales
# Segment            Consumer    Corporate  Home Office
# Category
# Furniture        391049.312  229019.7858  121930.6975
# Office Supplies  363952.136  230676.4620  124418.4340
# Technology       406399.897  246450.1190  183304.0170

# %%
pd.pivot_table(sample, index = ["Category"],values = ["Sales"], columns = ["Segment"],
              aggfunc=np.sum, fill_value=0,margins = True, margins_name="Total")
# Out:
#                        Sales
# Segment             Consumer    Corporate  Home Office         Total
# Category
# Furniture         391049.312  229019.7858  121930.6975  7.419998e+05
# Office Supplies   363952.136  230676.4620  124418.4340  7.190470e+05
# Technology        406399.897  246450.1190  183304.0170  8.361540e+05
# Total            1161401.345  706146.3668  429653.1485  2.297201e+06

# %%
pd.pivot_table(sample, index = ["Category","Segment"], values = ["Sales","Quantity"],
              aggfunc={"Sales":np.average,"Quantity":np.sum})
# Out:
#                              Quantity       Sales
# Category        Segment
# Furniture       Consumer         4166  351.347091
#                 Corporate        2495  354.519792
#                 Home Office      1367  336.825131
# Office Supplies Consumer        11758  116.390194
#                 Corporate        7018  126.745309
#                 Home Office      4130  115.309021
# Technology      Consumer         3597  427.339534
#                 Corporate        2095  444.855810
#                 Home Office      1247  535.976658

# %%
pd.pivot_table(sample, index = ["Category","Segment"], values = ["Sales","Quantity"],
              aggfunc={"Sales":[np.average,np.sum],"Quantity":np.sum})
# Out:
#                             Quantity       Sales
#                                  sum     average          sum
# Category        Segment
# Furniture       Consumer        4166  351.347091  391049.3120
#                 Corporate       2495  354.519792  229019.7858
#                 Home Office     1367  336.825131  121930.6975
# Office Supplies Consumer       11758  116.390194  363952.1360
#                 Corporate       7018  126.745309  230676.4620
#                 Home Office     4130  115.309021  124418.4340
# Technology      Consumer        3597  427.339534  406399.8970
#                 Corporate       2095  444.855810  246450.1190
#                 Home Office     1247  535.976658  183304.0170

# %%
table = pd.pivot_table(sample, index = ["Category","Segment"], values = ["Sales","Quantity"],
              aggfunc={"Sales":[np.average,np.sum],"Quantity":np.sum})

# %%
table.head()
# Out:
#                             Quantity       Sales
#                                  sum     average          sum
# Category        Segment
# Furniture       Consumer        4166  351.347091  391049.3120
#                 Corporate       2495  354.519792  229019.7858
#                 Home Office     1367  336.825131  121930.6975
# Office Supplies Consumer       11758  116.390194  363952.1360
#                 Corporate       7018  126.745309  230676.4620

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table.query('Segment == ["Corporate","Home Office"]')
# Out:
#                             Quantity       Sales
#                                  sum     average          sum
# Category        Segment
# Furniture       Corporate       2495  354.519792  229019.7858
#                 Home Office     1367  336.825131  121930.6975
# Office Supplies Corporate       7018  126.745309  230676.4620
#                 Home Office     4130  115.309021  124418.4340
# Technology      Corporate       2095  444.855810  246450.1190
#                 Home Office     1247  535.976658  183304.0170

# %%
sample.columns
# Out:
# Index(['Order Date', 'Customer Name', 'Segment', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Profit'],
#       dtype='object')

# %%
pivot = sample.query('Region == "East"').pivot_table(index="State",
                                                    columns = "Category",
                                                    values = "Sales",
                                                    aggfunc = "sum",
                                                    margins = True)

# %%
pivot.head()
# Out:
# Category              Furniture  Office Supplies  Technology        All
# State
# Connecticut            5174.987          5418.34     2791.03  13384.357
# Delaware               4759.319          8129.53    14562.22  27451.069
# District of Columbia   1346.580           138.52     1379.92   2865.020
# Maine                   109.480           399.80      761.25   1270.530
# Maryland               9149.253         10390.23     4166.04  23705.523

# %%
pivot
# Out:
# Category               Furniture  Office Supplies  Technology         All
# State
# Connecticut             5174.987         5418.340    2791.030   13384.357
# Delaware                4759.319         8129.530   14562.220   27451.069
# District of Columbia    1346.580          138.520    1379.920    2865.020
# Maine                    109.480          399.800     761.250    1270.530
# Maryland                9149.253        10390.230    4166.040   23705.523
# Massachusetts          10919.064        11988.740    5726.630   28634.434
# New Hampshire           1886.474         1769.250    3636.800    7292.524
# New Jersey              6307.042        14956.110   14501.160   35764.312
# New York               93372.729        90020.042  127483.500  310876.271
# Ohio                   24199.145        18382.999   35675.992   78258.136
# Pennsylvania           39354.931        34941.714   42215.269  116511.914
# Rhode Island            5918.756         6234.790   10474.410   22627.956
# ...

# %%
pivot.sort_values(by = "Furniture")
# Out:
# Category               Furniture  Office Supplies  Technology         All
# State
# Maine                    109.480          399.800     761.250    1270.530
# West Virginia            673.344          536.480         NaN    1209.824
# District of Columbia    1346.580          138.520    1379.920    2865.020
# New Hampshire           1886.474         1769.250    3636.800    7292.524
# Delaware                4759.319         8129.530   14562.220   27451.069
# Vermont                 5120.100         2209.510    1599.760    8929.370
# Connecticut             5174.987         5418.340    2791.030   13384.357
# Rhode Island            5918.756         6234.790   10474.410   22627.956
# New Jersey              6307.042        14956.110   14501.160   35764.312
# Maryland                9149.253        10390.230    4166.040   23705.523
# Massachusetts          10919.064        11988.740    5726.630   28634.434
# Ohio                   24199.145        18382.999   35675.992   78258.136
# ...

# %%
sales = pd.pivot_table(sample, index = ["Category"], values = ["Sales","Profit"],
                      aggfunc={"Sales":np.sum,"Profit":np.sum})

# %%
sales.head()
# Out:
#                       Profit        Sales
# Category
# Furniture         18451.2728  741999.7953
# Office Supplies  122490.8008  719047.0320
# Technology       145454.9481  836154.0330

# %%
sales.plot(kind="bar",title = "Sales vs Qty")
# Out:
# <AxesSubplot:title={'center':'Sales vs Qty'}, xlabel='Category'>

# %%
sales.plot(kind="line",title = "Sales vs Qty")
# Out:
# <AxesSubplot:title={'center':'Sales vs Qty'}, xlabel='Category'>

# %%
sample.head()
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
pd.pivot_table(sample, index = sample["Order Date"].dt.strftime("%B"), values = ["Sales"],
              aggfunc=np.sum).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   Segment        9994 non-null   object
#  3   City           9994 non-null   object
#  4   State          9994 non-null   object
#  5   Postal Code    9994 non-null   int64
#  6   Region         9994 non-null   object
#  7   Category       9994 non-null   object
#  8   Sub-Category   9994 non-null   object
#  9   Sales          9994 non-null   float64
#  10  Quantity       9994 non-null   int64
#  11  Profit         9994 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 937.1+ KB

# %%
sample["Order Date"] = sample["Order Date"].apply(pd.to_datetime)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   datetime64[ns]
#  1   Customer Name  9994 non-null   object
#  2   Segment        9994 non-null   object
#  3   City           9994 non-null   object
#  4   State          9994 non-null   object
#  5   Postal Code    9994 non-null   int64
#  6   Region         9994 non-null   object
#  7   Category       9994 non-null   object
#  8   Sub-Category   9994 non-null   object
#  9   Sales          9994 non-null   float64
#  10  Quantity       9994 non-null   int64
#  11  Profit         9994 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 937.1+ KB

# %%
pd.pivot_table(sample, index = sample["Order Date"].dt.strftime("%B"), values = ["Sales"],
              aggfunc=np.sum).sort_values(by = "Sales").plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
pd.pivot_table(sample, index = sample["Order Date"].dt.strftime("%B"), values = ["Sales"],
              aggfunc=np.sum).sort_values(by = "Sales").plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Order Date'>
